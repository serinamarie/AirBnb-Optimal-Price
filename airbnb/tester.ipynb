# %%
import requests
import json
import pandas as pd

# %%
url ="https://baseball-game-predictor.herokuapp.com/"
# url = 'http://127.0.0.1:5000/'

#Example JSON request 
dats = {"date":20080612,"day_of_week":"Thu","visiting_team":"MIN","visiting_team_league":"AL","home_team":"CLE","home_team_league":"AL","day_night":"N","park_id":126,"visiting_manager_name":"Ron Gardenhire","home_manager_name":"Eric Wedge"}
 
datsa = json.dumps(dats)

# %%
test_req = requests.post(url,datsa)
print(test_req)
# Out:
# <Response [200]>

# %%
print(test_req.json())
# Out:
# {'Winning team': 'CLE'}
